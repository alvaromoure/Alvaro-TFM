# %%
import numpy as np
import pandas as pd
from keras.models import load_model
from skimage import exposure,transform
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
UNet = load_model('/Users/alvaromoure/Desarrollo/UPM/TFM/Alvaro-TFM/segmenter/trained_model.hdf5')

# %%
img_path = '/Volumes/Alvaro HD/UPM/Corpus TFM/COVID/hackathon/test/P_3_1.png'
X = cv2.imread(img_path)
img = exposure.rescale_intensity(X,out_range=(0,1))
plt.imshow(img)
plt.show()

# %%
img = mor
